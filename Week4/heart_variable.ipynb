# %%
import heartpy as hp
import pandas as pd

# %%
# Out:
# 0   -63.191
# 1   -63.250
# 2   -63.952
# 3   -65.507
# 4   -67.588
# Name: I, dtype: float64

# %%
col_names = ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']
sample_rate = 500
df = pd.read_csv('../Week4/Sample_SB.csv', names=col_names)
data = df[col_names[0]]
filtered = hp.filter_signal(data, cutoff = 0.05, sample_rate = sample_rate, filtertype='notch')
wd, m = hp.process(hp.scale_data(filtered), sample_rate)
hp.plotter(wd, m)
# Out:
# c:\Users\sksoh\AppData\Local\Programs\Python\Python310\lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
col_names = ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']
sample_rate = 500
df = pd.read_csv('../Week4/Sample_SR.csv', names=col_names)
data = df[col_names[0]]
filtered = hp.filter_signal(data, cutoff = 0.05, sample_rate = sample_rate, filtertype='notch')
wd, m = hp.process(hp.scale_data(filtered), sample_rate)
hp.plotter(wd, m)
# Out:
# c:\Users\sksoh\AppData\Local\Programs\Python\Python310\lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
col_names = ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']
sample_rate = 500
df = pd.read_csv('../Week4/Sample_ST.csv', names=col_names)
data = df[col_names[0]]
filtered = hp.filter_signal(data, cutoff = 0.05, sample_rate = sample_rate, filtertype='notch')
wd, m = hp.process(hp.scale_data(filtered), sample_rate)
hp.plotter(wd, m)
# Out:
# c:\Users\sksoh\AppData\Local\Programs\Python\Python310\lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
